# %% [markdown]
# ## Riley Tomek
# ##DS4003 Final Project
#
# The data used was compiled from the following sources: The World Bank Group, CIA Factbook, OECD, UNESCO Institute for Statistics, Transparency.org, UNHCR, German Weather Service and independent research.

# %%
# Riley Tomek

"""
Why did I choose this dataset?

I've decided to redo the dashboard with the same data that is found here:
https://www.worlddata.info/quality-of-life.php?expats=0&stability=15&rights=20&health=15&safety=10&climate=1&costs=1&popularity=1#google_vignette

The data come from a variety of reputable sources for each different metric:
Some are from the World Bank, other metrics are from the United Nations,
and others are taken from the Institute for Economics & Peace. All sources
are listed in the previous link in detail. The dataset has then been uploaded
to Kaggle and is now accessible to all Kaggle users, along with the original dashboard

The goal of this dashboard is to provide a reasonable, accurate, and
distinctly clear analysis of countries in question. Whether someone is contemplating
moving, studying abroad, or just traveling, this will serve as a multi-faceted
data approach to making decisions, as opposed to single serve rankings
from before.

"""
# Out:
# "\nWhy did I choose this dataset?\n\nI've decided to redo the dashboard with the same data that is found here:\nhttps://www.worlddata.info/quality-of-life.php?expats=0&stability=15&rights=20&health=15&safety=10&climate=1&costs=1&popularity=1#google_vignette\n\nThe data come from a variety of reputable sources for each different metric:\nSome are from the World Bank, other metrics are from the United Nations, \nand others are taken from the Institute for Economics & Peace. All sources\nare listed in the previous link in detail. The dataset has then been uploaded \nto Kaggle and is now accessible to all Kaggle users, along with the original dashboard\n\nThe goal of this dashboard is to provide a reasonable, accurate, and \ndistinctly clear analysis of countries in question. Whether someone is contemplating \nmoving, studying abroad, or just traveling, this will serve as a multi-faceted\ndata approach to making decisions, as opposed to single serve rankings\nfrom before. \n\n"

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import plotly.express as px

#read data frame
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ccfc202-11a5-41b3-aa75-ca83896fe31f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ccfc202-11a5-41b3-aa75-ca83896fe31f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Quality of life in a country comparison.csv')

# %%
#each percentage does not refer to the weightings, its based on a previous dashboard
#linked here:https://www.worlddata.info/quality-of-life.php?expats=0&stability=15&rights=20&health=15&safety=10&climate=1&costs=1&popularity=1#google_vignette
#this dashboard allows the user to select their preferred weightings and then
#see the ranks that it spits out based on how much they prefer one factor over
#another. the goal is to redesign this dashboard and make the analysis more clear
# and allow user to do a more thorough analysis then just based on ratings

#rename columns so that easier to work with and more clear

df.rename(columns={'Rank': 'rank', 'Country':'country', 'Unnamed: 0': 'key', 'Stability(15%)': 'stability',
                   'Rights(20%)': 'rights', 'Health(15%)': 'health',
                   'Safety(10%)':'safety', 'Climate(15%)': 'climate',
                   'Costs(15%)': 'cost', 'Popularity(10%)': 'popularity',
                   'TotalQuality of life(100%)':'total_quality'}, inplace=True)
df.head()
# Out:
#    key  rank      country  stability  rights  health  safety  climate  cost  \
# 0    0     1    Australia         86      92      87     100       90    23
# 1    1     2   San Marino         81      82      91      87       62    61
# 2    2     3    Hong Kong         77      85     100      97       49    61
# 3    3     4  Switzerland         91      99      93      99       34    44
# 4    4     5        Macao         90      71     100      93       48    61
#
#    popularity  total_quality
# 0          41             76
# 1          47             74
# 2          41             74
# 3          46             74
# 4          44             73

# %%
df.describe()
# Out:
#               key        rank   stability      rights      health      safety  \
# count  137.000000  137.000000  137.000000  137.000000  137.000000  137.000000
# mean    68.000000   69.000000   57.576642   50.686131   58.124088   76.781022
# std     39.692569   39.692569   19.328706   25.142755   26.093284   21.791362
# min      0.000000    1.000000    8.000000    7.000000    0.000000    4.000000
# 25%     34.000000   35.000000   46.000000   32.000000   42.000000   69.000000
# 50%     68.000000   69.000000   57.000000   45.000000   63.000000   85.000000
# 75%    102.000000  103.000000   72.000000   72.000000   80.000000   93.000000
# max    136.000000  137.000000   93.000000  100.000000  100.000000  100.000000
#
#           climate        cost  popularity  total_quality
# count  137.000000  137.000000  137.000000     137.000000
# mean    53.233577   52.343066   37.978102      54.802920
# std     19.960720   11.612897   12.050425      10.887013
# ...

# %%
sns.histplot(data=df,  x='rights')
# Out:
# <Axes: xlabel='rights', ylabel='Count'>

# %%
sns.histplot(data=df,  x='cost')
# Out:
# <Axes: xlabel='cost', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='health')
# Out:
# <Axes: xlabel='health', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='popularity')
# Out:
# <Axes: xlabel='popularity', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='stability')
# Out:
# <Axes: xlabel='stability', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='rights')
# Out:
# <Axes: xlabel='rights', ylabel='Density'>

# %%
fig_line_basic = px.line(df,
                      x='rank', # x
                      y=['health', 'popularity','cost','stability','rights','safety','climate'],
                    title='Metrics by Rank'

)
# display the chart
fig_line_basic.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig_line_basic2 = px.scatter(df,
                      x='health', # x
                      y=['popularity','cost','stability','rights','safety','climate'],
                    title='Metrics by Health Factor'

)
# display the chart
fig_line_basic2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#reminder, rank is based on the previous weights, so not really relevant in this scenario.
#keep for future reference though, as comparison to what new application provides

"""
7. Finally, brainstorm a list of UI components that you could include in your dashboard. Consider what would be most useful or interesting for users.
8. Also brainstorm a list 3-6 possible data visualizations (e.g., a scatter plot of sepal length vs sepal width - this could be filtered on species using a multi-select dropdown)

Data Dictionary:
key: primary key for tracking across records for countries
rank: a default ranking of the previous dashboards arbitrary rankings
country: country name of the travel destination in question and comparison
stability: a number (1-100) indicating of medium- to long-term stability can be found in this area
rights: a number (1-100) indicating  the measures against corruption, how they’re perceived by the population, the corruption index, etc
health: a number (1-100) indicating general measure of public and personal health
safety: a number (1-100) indicating murder rate, as well as data on displaced persons, violent crime and ongoing wars
climate: a number (1-100) indicating a pleasant climate
cost: a number (1-100) indicating cost of living across a country
popularity: a number (1-100) of the general migration rate and the number of foreign tourists evaluated as indicators of a country's popularity
total_quality: a number (1-100) which is dictated by the rankings below* and a sum of all attributes above

*To arrive at an overall index for each country (in the old dashboard), the key figures
for the seven sub-sectors were included in an overall index in different proportions:
• Stability: 23%
• Civil rights: 31%
• Health services: 24%
• Safety: 16%
• Climate: 2%
• Costs: 2%
• Popularity: 2%

THIS is what the 'rank' variable is based on
"""

# %%
"""
Brain storm list of UI components

UI components could include direct comparison of one country to another, a multiselect
drop down that allows a user to directly look across data from
different countries on the metrics they value, rather than giving an arbritary weighting
as before in the other dashboard. Additionally, the user may want to 'save'
countries they can see they are interested in based on what they value.
This could be another multiselect, drop down , etc.

Additionally, visuals of the actual country's location could be important, and
bubble charts based on metrics could be clear visuals to give the
comparison a spatial understanding. Another visual could be stacked bar
plots for plotting multiple metrics, and dropdowns for selecting what metrics to
focus on.

Lastly, I believe a primary visual could be a radar chart, showing area of
the radar chart as a 'better' country compared to others. I'll have to make some
decisions data-wise to normalzie these values across the board and include that
so it is clear.
"""
